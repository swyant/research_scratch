# %%
from ase.io import read as ase_read
from ase.io import write as ase_write

# %%
input_file = "jp_dio-orig_min4.dump"
output_file = "jp_dio-orig_min4.xyz"

# %%
atoms = ase_read(input_file, format="lammps-dump-text", specorder=["Hf", "O"])

# %%
atoms

# %% [markdown]
# Atoms(symbols='Hf726648O178728' ... )
# 726648 Hf atoms
# 178728 O atoms

# %%
ase_write(output_file, atoms, format="extxyz")
