# %%
from ase.io import read as ase_read
from vesin import ase_neighbor_list

# %%
rlxd_polycrys_noO = ase_read("./111025_min4_no0_relaxed.xyz", format="extxyz")

# %%
i,j,S = ase_neighbor_list("ijS", rlxd_polycrys_noO, cutoff=10.4)

# %% [markdown]
# 22 minutes 18.5 seconds

# %%
S

# %%
import numpy as np

# %%
import h5py

# %%
np.savez_compressed("111025_min4_neighborlist_10dot4A.npz", i=i, j=j, S=S)
