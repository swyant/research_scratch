# %%
import numpy as np
import felupe as fem
import matplotlib.pyplot as plt

# %%
phi = np.linspace(1, 0.5, 21) * np.pi / 2

# %%
phi

# %%
#test = [np.cos(phi), np.sin(phi)] # just a list of numpy arrays
#test[1]
#test.shape
test = np.vstack([np.cos(phi),np.sin(phi)]) # an actual (2,21 multidiemnsional array)
#test.shape
#test.T.shape # (21,2)
test.T

# %%
line = fem.mesh.Line(n=21)

# %%
h = 1
L = 2
r = 0.3

# %%
curve = line.copy(points=r * np.vstack([np.cos(phi), np.sin(phi)]).T)
curve

# %%
line.plot()
