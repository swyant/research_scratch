# %%
from ase.io import read as ase_read
from vesin import ase_neighbor_list

# %%
orig_polycrystal = ase_read("./Hf.O.polycrystal.xyz", format="extxyz")

# %%
i,j,S = ase_neighbor_list("ijS", orig_polycrystal, cutoff=10.4)

# %% [markdown]
# 42 minutes 12.2 seconds
# I'm surprised because I thought it would be linear scaling but this is almost double? I suppose it maybe because the presenece of the O interstitial increases the search space for each cell

# %%
j

# %%
import numpy as np

# %%
np.savez_compressed("orig_dio_polycrystal_neighborlist10dot4n.pz", i=i, j=j, S=S)
